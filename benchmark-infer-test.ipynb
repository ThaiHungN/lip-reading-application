# %%
# !cd "Visual_Speech_Recognition_for_Multiple_Languages/benchmarks/LRS3/models" && gdown 1yHd4QwC7K_9Ro2OM_hC7pKUT2URPvm_f && unzip "LRS3_V_WER32.3.zip"
# !cd "Visual_Speech_Recognition_for_Multiple_Languages/benchmarks/LRS3/language_models" && gdown 1gh4ra__xuKb7yX9pNMe4ZwaSDKsCJlUe && unzip "lm_en.zip"

# %%
# vid_url = "https://www.lipreadingpractice.co.uk/media/video/00_introduction.mp4"
# !wget --content-disposition {vid_url} -O full_clip.mp4
# !ffmpeg -i full_clip.mp4  -ss 3 -t 11 -c copy clip.mp4
# !ffmpeg -i full_clip.mp4 -copyinkf -ss 0 -t 4 -c copy clip1.mp4
# !ffmpeg -i full_clip.mp4 -copyinkf -ss 3 -t 11 -c copy clip2.mp4

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = "noisy_clip.mp4"

with open(video_path, 'rb') as f:
    video_data = f.read()
    video_base64 = b64encode(video_data).decode()

video_html = f"""
<video width="640" height="360" controls>
    <source src="data:video/mp4;base64,{video_base64}" type="video/mp4">
</video>
"""

HTML(video_html)
# Out:
# <video width="640" height="360" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from time import time
import numpy as np

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../noisy_clip.mp4" \
    detector=retinaface
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# ...

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../noisy_clip.mp4" \
    detector=mediapipe
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FAITH
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FAITH
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FAITH
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FAITH
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: PROFOUND HEARING LOSSES ARE BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FAITH
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# ...

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../clip.mp4" \
    detector=retinaface
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# hyp: IM GOING TO GROW IT UP A GREAT
# Average time taken: 47.52 seconds
# Standard deviation: 1.34 seconds

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../clip.mp4" \
    detector=mediapipe
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: IM GOING TO GO TO THE MORNING
# Average time taken: 23.35 seconds
# Standard deviation: 0.75 seconds
# ...
