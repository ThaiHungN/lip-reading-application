# %%
# !cd "Visual_Speech_Recognition_for_Multiple_Languages/benchmarks/LRS3/models" && gdown 1yHd4QwC7K_9Ro2OM_hC7pKUT2URPvm_f && unzip "LRS3_V_WER32.3.zip"
# !cd "Visual_Speech_Recognition_for_Multiple_Languages/benchmarks/LRS3/language_models" && gdown 1gh4ra__xuKb7yX9pNMe4ZwaSDKsCJlUe && unzip "lm_en.zip"

# %%
# vid_url = "https://www.lipreadingpractice.co.uk/media/video/00_introduction.mp4"
# !wget --content-disposition {vid_url} -O full_clip2mp4
# !ffmpeg -i full_clip2mp4  -ss 3 -t 11 -c copy clip2mp4
# !ffmpeg -i full_clip2mp4 -copyinkf -ss 0 -t 4 -c copy clip1.mp4
# !ffmpeg -i full_clip2mp4 -copyinkf -ss 3 -t 11 -c copy clip2.mp4

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = "clip1.mp4"

with open(video_path, 'rb') as f:
    video_data = f.read()
    video_base64 = b64encode(video_data).decode()

video_html = f"""
<video width="640" height="360" controls>
    <source src="data:video/mp4;base64,{video_base64}" type="video/mp4">
</video>
"""

HTML(video_html)
# Out:
# <video width="640" height="360" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from time import time
import numpy as np

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../clip1.mp4" \
    detector=retinaface
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# hyp: HELLO IM GOING TO GO
# Average time taken: 53.30 seconds
# Standard deviation: 1.29 seconds

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../clip1.mp4" \
    detector=mediapipe
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: HELLO IM NOT GOING TO BE READY
# Average time taken: 22.55 seconds
# Standard deviation: 0.69 seconds
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../clip2.mp4" \
    detector=retinaface
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# hyp: I HAVE PROFOUND HEARING LOSSES ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS CAN FACE
# Average time taken: 128.46 seconds
# Standard deviation: 3.58 seconds

# %%
times = []
for i in range(10):
    start = time()    
    # !cd Visual_Speech_Recognition_for_Multiple_Languages && python infer.py \
    config_filename="./configs/LRS3_V_WER32.3.ini" \
    data_filename="../clip2.mp4" \
    detector=mediapipe
    end = time()
    # print(f"Time taken: {end-start:.2f} seconds")
    times.append(end-start)
avg_time = np.mean(times)
std_time = np.std(times)
print(f"Average time taken: {avg_time:.2f} seconds")
print(f"Standard deviation: {std_time:.2f} seconds")
# Out:
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# hyp: I HAVE PROFOUND HEARING LOSS ON BOTH THINGS SO I UNDERSTAND THE DIFFICULTIES THAT THOSE OF US WITH HEARING LOSS AND FACE
# Average time taken: 56.55 seconds
# Standard deviation: 0.87 seconds
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
